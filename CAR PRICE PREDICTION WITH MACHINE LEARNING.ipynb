# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns",None)

import pandas as psql

# %%
carprice=pd.read_csv(r"C:\Users\`sree123\Downloads\archive (2)\CarPrice_Assignment.csv",header=0)
carprice_bk=carprice.copy()
carprice.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
# ...

# %%
carprice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
carprice.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
del carprice['fueltype']

# %%
del carprice['aspiration']

# %%
del carprice['carbody']

# %%
del carprice['drivewheel']

# %%
del carprice['enginelocation']

# %%
del carprice['cylindernumber']

# %%
del carprice['fuelsystem']

# %%
del carprice['enginetype']

# %%
del carprice['CarName']

# %%
carprice.shape
# Out:
# (205, 17)

# %%
carprice['doornumber'].value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
carprice['doornumber']=carprice['doornumber'].str.replace('four','0')
carprice['doornumber']=carprice['doornumber'].str.replace('two','1')
carprice['doornumber']=carprice['doornumber'].astype(int)
carprice.head()
# Out:
#    car_ID  symboling  doornumber  wheelbase  carlength  carwidth  carheight  \
# 0       1          3           1       88.6      168.8      64.1       48.8
# 1       2          3           1       88.6      168.8      64.1       48.8
# 2       3          1           1       94.5      171.2      65.5       52.4
# 3       4          2           0       99.8      176.6      66.2       54.3
# 4       5          2           0       99.4      176.6      66.4       54.3
#
#    curbweight  enginesize  boreratio  stroke  compressionratio  horsepower  \
# 0        2548         130       3.47    2.68               9.0         111
# 1        2548         130       3.47    2.68               9.0         111
# 2        2823         152       2.68    3.47               9.0         154
# 3        2337         109       3.19    3.40              10.0         102
# 4        2824         136       3.19    3.40               8.0         115
#
#    peakrpm  citympg  highwaympg    price
# ...

# %%
carprice.nunique()
# Out:
# car_ID              205
# symboling             6
# doornumber            2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginesize           44
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
carprice.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# doornumber          0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginesize          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
carprice.head()
# Out:
#    car_ID  symboling  doornumber  wheelbase  carlength  carwidth  carheight  \
# 0       1          3           1       88.6      168.8      64.1       48.8
# 1       2          3           1       88.6      168.8      64.1       48.8
# 2       3          1           1       94.5      171.2      65.5       52.4
# 3       4          2           0       99.8      176.6      66.2       54.3
# 4       5          2           0       99.4      176.6      66.4       54.3
#
#    curbweight  enginesize  boreratio  stroke  compressionratio  horsepower  \
# 0        2548         130       3.47    2.68               9.0         111
# 1        2548         130       3.47    2.68               9.0         111
# 2        2823         152       2.68    3.47               9.0         154
# 3        2337         109       3.19    3.40              10.0         102
# 4        2824         136       3.19    3.40               8.0         115
#
#    peakrpm  citympg  highwaympg    price
# ...

# %%
#identify the independent and target variables

carprice_dup=carprice[carprice.duplicated(keep='last')]

#display the duplicate records

carprice_dup
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, doornumber, wheelbase, carlength, carwidth, carheight, curbweight, enginesize, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []

# %%
carprice.columns
# Out:
# Index(['car_ID', 'symboling', 'doornumber', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginesize', 'boreratio',
#        'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'citympg',
#        'highwaympg', 'price'],
#       dtype='object')

# %%
#display information

carprice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   doornumber        205 non-null    int32
#  3   wheelbase         205 non-null    float64
#  4   carlength         205 non-null    float64
#  5   carwidth          205 non-null    float64
#  6   carheight         205 non-null    float64
#  7   curbweight        205 non-null    int64
#  8   enginesize        205 non-null    int64
#  9   boreratio         205 non-null    float64
#  10  stroke            205 non-null    float64
#  11  compressionratio  205 non-null    float64
#  12  horsepower        205 non-null    int64
#  13  peakrpm           205 non-null    int64
#  14  citympg           205 non-null    int64
#  15  highwaympg        205 non-null    int64
# ...

# %%
carprice.describe()
# Out:
#            car_ID   symboling  doornumber   wheelbase   carlength    carwidth  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146    0.439024   98.756585  174.049268   65.907805
# std     59.322565    1.245307    0.497483    6.021776   12.337289    2.145204
# min      1.000000   -2.000000    0.000000   86.600000  141.100000   60.300000
# 25%     52.000000    0.000000    0.000000   94.500000  166.300000   64.100000
# 50%    103.000000    1.000000    0.000000   97.000000  173.200000   65.500000
# 75%    154.000000    2.000000    1.000000  102.400000  183.100000   66.900000
# max    205.000000    3.000000    1.000000  120.900000  208.100000   72.300000
#
#         carheight   curbweight  enginesize   boreratio      stroke  \
# count  205.000000   205.000000  205.000000  205.000000  205.000000
# mean    53.724878  2555.565854  126.907317    3.329756    3.255415
# ...

# %%
carprice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   doornumber        205 non-null    int32
#  3   wheelbase         205 non-null    float64
#  4   carlength         205 non-null    float64
#  5   carwidth          205 non-null    float64
#  6   carheight         205 non-null    float64
#  7   curbweight        205 non-null    int64
#  8   enginesize        205 non-null    int64
#  9   boreratio         205 non-null    float64
#  10  stroke            205 non-null    float64
#  11  compressionratio  205 non-null    float64
#  12  horsepower        205 non-null    int64
#  13  peakrpm           205 non-null    int64
#  14  citympg           205 non-null    int64
#  15  highwaympg        205 non-null    int64
# ...

# %%
carprice=carprice.drop_duplicates()

carprice.shape
# Out:
# (205, 17)

# %%
IndepVar = []
for col in carprice.columns:
    if col != 'price':
        IndepVar.append(col)
TargetVar = 'price'

x = carprice[IndepVar]
y = carprice[TargetVar]

# %%
# Split the data into Train and Test(random samping)

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# Display shape for train and test data

x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((143, 16), (62, 16), (143,), (62,))

# %%
from sklearn.preprocessing import MinMaxScaler

mmscaler =  MinMaxScaler(feature_range=(0,1))

x_train =  mmscaler.fit_transform(x_train)
x_train = pd.DataFrame(x_train)

x_test = mmscaler.fit_transform(x_test)
x_test = pd.DataFrame(x_test)

# %% [markdown]
# # Regression Algorithm

# %%
#train the algorithm and build the model with train dataset
from sklearn.linear_model import LinearRegression
#create an object for regression model
model = LinearRegression()
#train the model with training dataset
model.fit(x_train,y_train)
#predict the model with test dataset
y_pred = model.predict(x_test)

# %%
#evaluation metrics for  the regression model
from sklearn import metrics
print("mean absolute error:",round(metrics.mean_absolute_error(y_test,y_pred),3))
print("mean squared error:",round(metrics.mean_squared_error(y_test,y_pred),3))
print("root mean squared error:",round(np.sqrt(metrics.mean_squared_error(y_test,y_pred)),3))
print("R2 score:",round(metrics.r2_score(y_test,y_pred),3))
print("mean absolute percentage error:",round(metrics.mean_absolute_percentage_error(y_test,y_pred)*100,3),'%')
print("root mean square log error:",round(np.log(np.sqrt(metrics.mean_squared_error(y_test,y_pred))),3))
# Out:
# mean absolute error: 4121.213
# mean squared error: 23461001.095
# root mean squared error: 4843.656
# R2 score: 0.661
# mean absolute percentage error: 38.473 %
# root mean square log error: 8.485

# %%
# Define the function to calculate the MAPE - Mean Absolute Percentage Error

def MAPE (y_test, y_pred): 
    y_test, y_pred = np.array(y_test), np.array(y_pred)
    return np.mean(np.abs((y_test - y_pred) / y_test)) * 100

# Evaluation of MAPE 

result = MAPE(y_test, y_pred)
print('Mean Absolute Percentage Error (MAPE):', round(result, 3), '%')
# Out:
# Mean Absolute Percentage Error (MAPE): 38.473 %

# %%
# Calculate Adjusted R squared values 

r_squared = round(metrics.r2_score(y_test, y_pred),6)
adjusted_r_squared = round(1 - (1-r_squared)*(len(y)-1)/(len(y)-x.shape[1]-1),6)
print('Adj R Square: ', adjusted_r_squared)
# Out:
# Adj R Square:  0.632562

# %%
# Display the Final results 

Results = pd.DataFrame({'Expenses_A':y_test, 'Expenses_P':y_pred})

# Merge two Dataframes on index of both the dataframes

ResultsFinal = carprice_bk.merge(Results, left_index=True, right_index=True) #both indices should be equal

ResultsFinal['%Error']=round(((ResultsFinal['Expenses_A']-ResultsFinal['Expenses_P'])))

# Display 10 records randomly

ResultsFinal.sample(5)
# Out:
#      car_ID  symboling                    CarName fueltype aspiration  \
# 84       85          3       mitsubishi mirage g4      gas      turbo
# 19       20          1      chevrolet monte carlo      gas        std
# 29       30          3  dodge coronet custom (sw)      gas      turbo
# 159     160          0             toyota corolla   diesel        std
# 191     192          0          volkswagen rabbit      gas        std
#
#     doornumber    carbody drivewheel enginelocation  wheelbase  carlength  \
# 84         two  hatchback        fwd          front       95.9      173.2
# 19         two  hatchback        fwd          front       94.5      155.9
# 29         two  hatchback        fwd          front       95.9      173.2
# 159       four  hatchback        fwd          front       95.7      166.3
# 191       four      sedan        fwd          front      100.4      180.2
#
#      carwidth  carheight  curbweight enginetype cylindernumber  enginesize  \
# ...
